# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../00_data/07_combined_clean_no_norm.csv")

# %%
df
# Out:
#            chain category_clean                  item_name serve_size  \
# 0     McDondalds       beverage      Vanilla Shake (Small)     340,96
# 1     McDondalds       beverage      Vanilla Shake (Small)     340,96
# 2     McDondalds       beverage      Vanilla Shake (Small)     340,96
# 3     McDondalds       beverage      Vanilla Shake (Small)     340,96
# 4     McDondalds       beverage      Vanilla Shake (Small)     340,96
# ...          ...            ...                        ...        ...
# 5775      Subway       beverage  Coca-Cola Classic (Child)     340,96
# 5776      Subway       beverage  Coca-Cola Classic (Child)     340,96
# 5777      Subway       beverage  Coca-Cola Classic (Child)     340,96
# 5778      Subway       beverage  Coca-Cola Classic (Child)     340,96
# 5779      Subway       beverage  Coca-Cola Classic (Child)     340,96
#
#      serve_size_unit nutrition_indicator value_per_serving
# 0                 ml       calories_kcal               530
# ...

# %%
df = df.loc[df["nutrition_indicator"] != "trans_fat_g"]

# %%
df
# Out:
#            chain category_clean                  item_name serve_size  \
# 0     McDondalds       beverage      Vanilla Shake (Small)     340,96
# 1     McDondalds       beverage      Vanilla Shake (Small)     340,96
# 2     McDondalds       beverage      Vanilla Shake (Small)     340,96
# 4     McDondalds       beverage      Vanilla Shake (Small)     340,96
# 5     McDondalds       beverage      Vanilla Shake (Small)     340,96
# ...          ...            ...                        ...        ...
# 5775      Subway       beverage  Coca-Cola Classic (Child)     340,96
# 5776      Subway       beverage  Coca-Cola Classic (Child)     340,96
# 5777      Subway       beverage  Coca-Cola Classic (Child)     340,96
# 5778      Subway       beverage  Coca-Cola Classic (Child)     340,96
# 5779      Subway       beverage  Coca-Cola Classic (Child)     340,96
#
#      serve_size_unit nutrition_indicator value_per_serving
# 0                 ml       calories_kcal               530
# ...

# %%
# deleted the rows including "nutrition_indicator" = "trans_fat" --> because the WHO data does not include the information.

# %%
df.to_csv("../00_data/08_combined_data.csv", index=False)

# %% [markdown]
# # ATTENTION:
#
# ### Data has been cleaned in excel.
# - For McDonalds salad sauces, the Cholesterol value has been set to 0, as no value available.
# - For subway Kidsmenue, the Cholesterol value has been set to 0, as no value available.
#
# ---> Version to be used: 08_01_combined_data_excel_cleaned.csv
