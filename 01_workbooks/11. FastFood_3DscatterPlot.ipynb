# %% [markdown]
# ## 3D Scatterplot with plotly

# %%
# importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# putting the data into a dataframe

menu = pd.read_csv('00_comibined_final.csv')
menu.head(2)
# Out:
#         chain category_clean          item_name  serve_size serve_size_unit  \
# 0  McDondalds      breakfast       Egg McMuffin       136.0               g
# 1  McDondalds      breakfast  Egg White Delight       135.0               g
#
#    calories_kcal  total_fat_g  saturated_fat_g  trans_fat_g  cholesterol_mg  \
# 0            300         13.0              5.0          0.0           260.0
# 1            250          8.0              3.0          0.0            25.0
#
#    ...  calories_kcal_norm  total_fat_norm  saturated_fat_norm  \
# 0  ...              220.59            9.56                3.68
# 1  ...              185.19            5.93                2.22
#
#    trans_fat_norm  cholesterol_norm  sodium_norm  carbohydrates_norm  \
# 0             0.0            191.18       551.47               22.79
# 1             0.0             18.52       570.37               22.22
#
#    dietary_fiber_norm  sugars_norm  protein_norm
# 0                2.94         2.21         12.50
# ...

# %%
# Check for Nulls
print(menu.isnull().any())
print("--------------------------------------")
# check for numbers
print(menu.describe())
print("--------------------------------------")
# Out:
# chain                 False
# category_clean        False
# item_name             False
# serve_size            False
# serve_size_unit       False
# calories_kcal         False
# total_fat_g            True
# saturated_fat_g        True
# trans_fat_g            True
# cholesterol_mg         True
# sodium_mg             False
# carbohydrates_g       False
# dietary_fiber_g       False
# sugars_g              False
# protein_g             False
# calories_kcal_norm    False
# total_fat_norm         True
# saturated_fat_norm     True
# trans_fat_norm         True
# cholesterol_norm       True
# sodium_norm           False
# carbohydrates_norm    False
# dietary_fiber_norm    False
# sugars_norm           False
# protein_norm          False
# dtype: bool
# --------------------------------------
#         serve_size  calories_kcal  total_fat_g  saturated_fat_g  trans_fat_g  \
# count   558.000000     558.000000   544.000000       531.000000   545.000000
# ...

# %%
# 3D scatter plot for calories

trace1 = go.Scatter3d(
    x=menu['category_clean'].values,
    y=menu['item_name'].values,
    z=menu['calories_kcal'].values,
    text=menu['item_name'].values,
    mode='markers',
    marker=dict(
        sizemode='diameter',
#         sizeref=750,
#         size= dailyValue['Cholesterol (% Daily Value)'].values,
        color = menu['calories_kcal'].values,
        colorscale = 'Portland',
        colorbar = dict(title = 'calories_kcal'),
        line=dict(color='rgb(255, 255, 255)')
    )
)

data=[trace1]
layout=dict(height=800, width=800, title='3D Scatter Plot of calories_kcal')
fig=dict(data=data, layout=layout)
py.iplot(fig, filename='3DBubble')
# Out:
# <div>
#
#
#             <div id="5abba861-ef91-422d-840c-70fb06e4e8f5" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5abba861-ef91-422d-840c-70fb06e4e8f5")) {
#                     Plotly.newPlot(
#                         '5abba861-ef91-422d-840c-70fb06e4e8f5',
# ...
