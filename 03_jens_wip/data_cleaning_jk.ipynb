# %% [markdown]
# # Jens: Anfang

# %%
import pandas as pd
import numpy as np
import re

# %%
burger_king = pd.read_csv("../00_data/burger_king_nutrition.csv", sep=";")
#burger_king = pd.read_csv("project_fastfood_nutrition\00_data", sep=";")

# %%
burger_king.tail()
# Out:
#                              item_name   category Serving Size (g)  Calories  \
# 171    BK® Café Mocha Frappe- 16 fl oz  BEVERAGES         16 fl oz       400
# 172    BK® Café Mocha Frappe- 20 fl oz  BEVERAGES         20 fl oz       510
# 173  BK® Café Caramel Frappe- 12 fl oz  BEVERAGES         12 fl oz       300
# 174  BK® Café Caramel Frappe- 16 fl oz  BEVERAGES         16 fl oz       400
# 175  BK® Café Caramel Frappe- 20 fl oz  BEVERAGES         20 fl oz       500
#
#      Calories from fat  Total fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# 171                 90           10.0                7.0            0.0
# 172                110           13.0                8.0            0.0
# 173                 80            8.0                5.0            0.0
# 174                 90           10.0                7.0            0.0
# 175                110           12.0                8.0            0.0
#
#      Chol (mg)  Sodium (mg)  Total Carb (g)  Dietary Fiber (g)  \
# ...

# %%
#burger_king = burger_king.drop(['Unnamed: 14',
#       'Unnamed: 15'], 1)

# %%
burger_king.dtypes
# Out:
# item_name             object
# category              object
# Serving Size (g)      object
# Calories               int64
# Calories from fat      int64
# Total fat (g)        float64
# Saturated Fat (g)    float64
# Trans Fat (g)        float64
# Chol (mg)              int64
# Sodium (mg)            int64
# Total Carb (g)         int64
# Dietary Fiber (g)      int64
# Total Sugar (g)        int64
# Protein (g)            int64
# Unnamed: 14          float64
# Unnamed: 15          float64
# dtype: object

# %%
burger_king["Serving Size (g)"].value_counts()
# Out:
# 20 fl oz    17
# 16 fl oz    17
# 29 fl oz    11
# 12 fl oz    11
# 38 fl oz     9
#             ..
# 102          1
# 303          1
# 11           1
# 242          1
# 231          1
# Name: Serving Size (g), Length: 92, dtype: int64

# %%
# Diese Codes sind ersetzen all "xx fl oz" zu dem Wert in "ml" 

burger_king["Serving Size (g)"].replace('20 fl oz', '591', inplace=True)
burger_king["Serving Size (g)"].replace('16 fl oz', '455', inplace=True)
burger_king["Serving Size (g)"].replace('29 fl oz', '824', inplace=True)
burger_king["Serving Size (g)"].replace('12 fl oz', '341', inplace=True)
burger_king["Serving Size (g)"].replace('38 fl oz', '1080', inplace=True)

# %%
# Hiermit habe ich überprüft, dass es keine "xx fl oz" mehr gibt

burger_king["Serving Size (g)"].value_counts()
# Out:
# 455     17
# 591     17
# 824     11
# 341     11
# 1080     9
#         ..
# 249      1
# 102      1
# 303      1
# 11       1
# 231      1
# Name: Serving Size (g), Length: 92, dtype: int64

# %%
# bei Subway muss man nichts ändern, da passen die Angaben.

# %%
subway = pd.read_csv("../00_data/subway_nutrition.csv", sep=";")

# %%
subway.head()
# Out:
#    category                   item_name  serving_size_g  calories_kcal  \
# 0  Sandwich                     BBQ Rib             208            580
# 1  Sandwich            Black Forest Ham             219            260
# 2  Sandwich  Chicken & Bacon Ranch Melt             284            540
# 3  Sandwich         Chicken Mango Curry             234            330
# 4  Sandwich               Chicken Tikka             205            290
#
#   total_fat_g saturated_fat_g trans_fat_g  cholesterol_mg  sodium_mg  \
# 0          31              10           0              60       1260
# 1           4               1           0              30        750
# 2          26              10         0,5             100       1100
# 3           7             1,5           0              50        840
# 4           5               1           0              50        720
#
#    carbohydrates_g  dietary_fiber_g  sugars_g  protein_g  vitamin_A_%DV  \
# ...

# %%
subway["serving_size_g"].value_counts()
# Out:
# 14     14
# 45      6
# 75      5
# 47      4
# 18      3
#        ..
# 382     1
# 198     1
# 68      1
# 65      1
# 1       1
# Name: serving_size_g, Length: 67, dtype: int64

# %%
mcdonalds = pd.read_csv("../00_data/McDoanlds_menu_fromKaggle.csv")

# %%
mcdonalds.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
mcdonalds["Serving Size"].value_counts()
# Out:
# 16 fl oz cup       45
# 12 fl oz cup       38
# 22 fl oz cup       20
# 20 fl oz cup       16
# 21 fl oz cup        7
#                    ..
# 4.8 oz (136 g)      1
# 5.2 oz (147 g)      1
# 6.4 oz (182 g)      1
# 10.5 oz (297 g)     1
# 2.6 oz (75 g)       1
# Name: Serving Size, Length: 107, dtype: int64

# %%
# Anpassen der Werte für Flüssigkeiten

mcdonalds["Serving Size"].replace('16 fl oz cup', '455', inplace=True)
mcdonalds["Serving Size"].replace('12 fl oz cup', '341', inplace=True)
mcdonalds["Serving Size"].replace('22 fl oz cup', '625', inplace=True)
mcdonalds["Serving Size"].replace('20 fl oz cup', '568', inplace=True)
mcdonalds["Serving Size"].replace('21 fl oz cup', '597', inplace=True)
mcdonalds["Serving Size"].replace('30 fl oz cup', '852', inplace=True)

# %%
mcdonalds["Serving Size"].value_counts()
# Out:
# 455    45
# 341    38
# 625    20
# 568    16
# 852     7
#        ..
# 136     1
# 207     1
# 318     1
# 434     1
# 213     1
# Name: Serving Size, Length: 107, dtype: int64

# %%
mcdonalds["Serving Size"].replace('4.8 oz (136 g)', '136', inplace=True)
mcdonalds["Serving Size"].replace('5.2 oz (147 g)', '147', inplace=True)
mcdonalds["Serving Size"].replace('6.4 oz (182 g)', '182', inplace=True)
mcdonalds["Serving Size"].replace('10.5 oz (297 g)', '297', inplace=True)
mcdonalds["Serving Size"].replace('2.6 oz (75 g)', '75', inplace=True)

mcdonalds["Serving Size"].replace('1.3 oz (38 g)', '38', inplace=True)
mcdonalds["Serving Size"].replace('5.9 oz (168 g)', '168', inplace=True)
mcdonalds["Serving Size"].replace('6.3 oz (179 g)', '179', inplace=True)
mcdonalds["Serving Size"].replace('11.2 oz (318 g)', '318', inplace=True)
mcdonalds["Serving Size"].replace('2.7 oz (77 g)', '77', inplace=True)

mcdonalds["Serving Size"].replace('7.3 oz (207 g)', '207', inplace=True)
mcdonalds["Serving Size"].replace('5.7 oz (163 g)', '163', inplace=True)
mcdonalds["Serving Size"].replace('5.2 oz (148 g)', '148', inplace=True)
mcdonalds["Serving Size"].replace('5 oz (143 g)', '143', inplace=True)

mcdonalds["Serving Size"].replace('11.1 oz (316 g)', '316', inplace=True)
mcdonalds["Serving Size"].replace('10.1 oz (285 g)', '285', inplace=True)
mcdonalds["Serving Size"].replace('8 oz (227 g)', '227', inplace=True)
mcdonalds["Serving Size"].replace('11.4 oz (323 g)', '323', inplace=True)
mcdonalds["Serving Size"].replace('5.4 oz (153 g)', '153', inplace=True)

mcdonalds["Serving Size"].replace('7.2 oz (205 g)', '205', inplace=True)
mcdonalds["Serving Size"].replace('7.3 oz (208 g)', '208', inplace=True)
mcdonalds["Serving Size"].replace('22.8 oz (646 g)', '646', inplace=True)
mcdonalds["Serving Size"].replace('5.3 oz (150 g)', '150', inplace=True)
mcdonalds["Serving Size"].replace('6 oz (171 g)', '171', inplace=True)

mcdonalds["Serving Size"].replace('7.6 oz (217 g)', '217', inplace=True)
mcdonalds["Serving Size"].replace('7.4 oz (211 g)', '211', inplace=True)
mcdonalds["Serving Size"].replace('7.5 oz (213 g)', '213', inplace=True)
mcdonalds["Serving Size"].replace('15.3 oz (434 g)', '434', inplace=True)
mcdonalds["Serving Size"].replace('5.5 oz (157 g)', '157', inplace=True)
mcdonalds["Serving Size"].replace('4.6 oz (131 g)', '131', inplace=True)
mcdonalds["Serving Size"].replace('6.1 oz (174 g)', '174', inplace=True)

# %%
mcdonalds.groupby("Serving Size").count()
# Out:
#                    Category  Item  Calories  Calories from Fat  Total Fat  \
# Serving Size
# 1 carton (236 ml)         2     2         2                  2          2
# 1 cookie (33 g)           2     2         2                  2          2
# 1 oz (29 g)               1     1         1                  1          1
# 1.2 oz (34 g)             1     1         1                  1          1
# 10 oz (283 g)             2     2         2                  2          2
# ...                     ...   ...       ...                ...        ...
# 9 oz (255 g)              1     1         1                  1          1
# 9.5 oz (269 g)            1     1         1                  1          1
# 9.5 oz (270 g)            2     2         2                  2          2
# 9.6 oz (251 g)            2     2         2                  2          2
# 9.6 oz (272 g)            1     1         1                  1          1
#
#                    Total Fat (% Daily Value)  Saturated Fat  \
# ...

# %%
mcdonalds.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin             136       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
mcdonalds.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
split_serving_size = mcdonalds["Serving Size"].str.split(pat=" ", expand = True)


#mcdonalds["Serving Size"].replace('(', '', inplace=True)
#mcdonalds

# %%
split_serving_size
# Out:
#         0     1     2     3     4
# 0     136  None  None  None  None
# 1     4.8    oz  (135    g)  None
# 2     3.9    oz  (111    g)  None
# 3     5.7    oz  (161    g)  None
# 4     5.7    oz  (161    g)  None
# ..    ...   ...   ...   ...   ...
# 255   285  None  None  None  None
# 256  13.4    oz  (381    g)  None
# 257   6.7    oz  (190    g)  None
# 258  14.2    oz  (403    g)  None
# 259   7.1    oz  (202    g)  None
#
# [260 rows x 5 columns]

# %%
split_serving_size = split_serving_size.rename(columns = {2:"Test"})

# %%
for i in len(split_serving_size):
        if

# %%
split_serving_size["Test"].replace("(","",inplace=True)

# %%
print(split_serving_size["Test"].isnumeric().any())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-0cf3d7931d40> in <module>
# ----> 1 print(split_serving_size["Test"].isnumeric().any())
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'isnumeric'

# %% [markdown]
# # Jens: ENDE

# %% [markdown]
# ### Starting with McDonals Data

# %%
mcdonalds.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
# selecting only the columns needed

mcdonalds.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
mcdonalds = mcdonalds[['Category', 'Item', 'Serving Size', 'Calories',
       'Total Fat', 'Saturated Fat', 'Trans Fat', 'Cholesterol', 'Sodium',
       'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein']].copy()

# %%
mcdonalds.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Total Fat  Saturated Fat  Trans Fat  Cholesterol  Sodium  Carbohydrates  \
# 0       13.0            5.0        0.0          260     750             31
# 1        8.0            3.0        0.0           25     770             30
# 2       23.0            8.0        0.0           45     780             29
# 3       28.0           10.0        0.0          285     860             30
# 4       23.0            8.0        0.0           50     880             30
#
#    Dietary Fiber  Sugars  Protein
# 0              4       3       17
# ...

# %%
# check serving size column 

mcdonalds["Serving Size"].value_counts()
# Out:
# 16 fl oz cup       45
# 12 fl oz cup       38
# 22 fl oz cup       20
# 20 fl oz cup       16
# 30 fl oz cup        7
#                    ..
# 2.6 oz (75 g)       1
# 5.7 oz (162 g)      1
# 11.1 oz (316 g)     1
# 4.3 oz (121 g)      1
# 7.3 oz (207 g)      1
# Name: Serving Size, Length: 107, dtype: int64

# %% [markdown]
# #### --> the serving sizes are noted very differently by all 3 restaurants. Will come back to clean the data later.

# %%
current_name = ['Category', 'Item', 'Serving Size', 'Calories', 'Total Fat',
       'Saturated Fat', 'Trans Fat', 'Cholesterol', 'Sodium', 'Carbohydrates',
       'Dietary Fiber', 'Sugars', 'Protein']
new_name = ['category', 'item_name', 'serving_size_g', 'calories_kcal',
       'total_fat_g', 'saturated_fat_g', 'trans_fat_g', 'cholesterol_mg',
       'sodium_mg', 'carbohydrates_g', 'dietary_fiber_g', 'sugars_g',
       'protein_g']

name_dict = dict(zip(current_name, new_name))
name_dict
# Out:
# {'Category': 'category',
#  'Item': 'item_name',
#  'Serving Size': 'serving_size_g',
#  'Calories': 'calories_kcal',
#  'Total Fat': 'total_fat_g',
#  'Saturated Fat': 'saturated_fat_g',
#  'Trans Fat': 'trans_fat_g',
#  'Cholesterol': 'cholesterol_mg',
#  'Sodium': 'sodium_mg',
#  'Carbohydrates': 'carbohydrates_g',
#  'Dietary Fiber': 'dietary_fiber_g',
#  'Sugars': 'sugars_g',
#  'Protein': 'protein_g'}

# %%
mcdonalds = mcdonalds.rename(columns = name_dict).copy()

# %%
mcdonalds.head()
# Out:
#     category                         item_name  serving_size_g  calories_kcal  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)            300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)            250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)            370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)            450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)            400
#
#    total_fat_g  saturated_fat_g  trans_fat_g  cholesterol_mg  sodium_mg  \
# 0         13.0              5.0          0.0             260        750
# 1          8.0              3.0          0.0              25        770
# 2         23.0              8.0          0.0              45        780
# 3         28.0             10.0          0.0             285        860
# 4         23.0              8.0          0.0              50        880
#
#    carbohydrates_g  dietary_fiber_g  sugars_g  protein_g
# ...

# %% [markdown]
# ### Continue with Burger King data

# %%
burger_king.dtypes
# Out:
# item_name             object
# category              object
# Serving Size (g)      object
# Calories               int64
# Calories from fat      int64
# Total fat (g)        float64
# Saturated Fat (g)    float64
# Trans Fat (g)        float64
# Chol (mg)              int64
# Sodium (mg)            int64
# Total Carb (g)         int64
# Dietary Fiber (g)      int64
# Total Sugar (g)        int64
# Protein (g)            int64
# dtype: object

# %% [markdown]
# ####  --> serving size is here messy as well. The column names are already clean.

# %% [markdown]
# ### Check subway data

# %%
subway.dtypes
# Out:
# category           object
# item_name          object
# serving_size_g      int64
# calories_kcal       int64
# total_fat_g        object
# saturated_fat_g    object
# trans_fat_g        object
# cholesterol_mg      int64
# sodium_mg           int64
# carbohydrates_g     int64
# dietary_fiber_g     int64
# sugars_g            int64
# protein_g           int64
# vitamin_A_%DV       int64
# vitamin_B_%DV       int64
# calcium_%DV         int64
# iron_%DV            int64
# dtype: object

# %%
subway.columns
# Out:
# Index(['category', 'item_name', 'serving_size_g', 'calories_kcal',
#        'total_fat_g', 'saturated_fat_g', 'trans_fat_g', 'cholesterol_mg',
#        'sodium_mg', 'carbohydrates_g', 'dietary_fiber_g', 'sugars_g',
#        'protein_g', 'vitamin_A_%DV', 'vitamin_B_%DV', 'calcium_%DV',
#        'iron_%DV'],
#       dtype='object')

# %%
subway = subway[['category', 'item_name', 'serving_size_g', 'calories_kcal',
       'total_fat_g', 'saturated_fat_g', 'trans_fat_g', 'cholesterol_mg',
       'sodium_mg', 'carbohydrates_g', 'dietary_fiber_g', 'sugars_g',
       'protein_g']].copy()

# %%
subway
# Out:
#            category                   item_name  serving_size_g  \
# 0          Sandwich                     BBQ Rib             208
# 1          Sandwich            Black Forest Ham             219
# 2          Sandwich  Chicken & Bacon Ranch Melt             284
# 3          Sandwich         Chicken Mango Curry             234
# 4          Sandwich               Chicken Tikka             205
# ..              ...                         ...             ...
# 112  bread_toppings                    Tomatoes              35
# 113  bread_toppings                       Bacon              15
# 114  bread_toppings                   Guacamole              35
# 115  bread_toppings                Shaved Steak             100
# 116  bread_toppings             Parmesan Cheese               1
#
#      calories_kcal total_fat_g saturated_fat_g trans_fat_g  cholesterol_mg  \
# 0              580          31              10           0              60
# ...

# %% [markdown]
# ### Harmonize the category of all 3 resturants

# %%
subway["category"].value_counts()
# Out:
# Sandwich          31
# bread_toppings    22
# Wraps             19
# bread             15
# Extras            13
# Sauces            12
# Breakfast          4
# Salad              1
# Name: category, dtype: int64

# %%
mcdonalds["category"].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: category, dtype: int64

# %%
burger_king["category"].value_counts()
# Out:
# BEVERAGES                71
# BREAKFAST                33
# CHICKEN & MORE           18
# KING JR™ MEALS           17
# SALADS & SIDES           15
# FLAME BROILED BURGERS    14
# WHOPPER® SANDWICHES       8
# Name: category, dtype: int64

# %% [markdown]
# ### pickle the file for Jens to work on regex

# %%
subway.to_pickle("../00_data/01_subway_wip.pkl")

# %%
burger_king.to_pickle("../00_data/02_burger_king_wip.pkl")

# %%
mcdonalds.to_pickle("../00_data/03_mcdonalds_wip.pkl")
