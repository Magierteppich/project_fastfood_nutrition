# %% [markdown]
# # There are still some categories to be cleaned

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle("../00_data/00_comibined_clean_normalized.pkl")

# %%
df.head()
# Out:
#         chain category_clean                         item_name  serve_size  \
# 0  McDondalds      breakfast                      Egg McMuffin       136.0
# 1  McDondalds      breakfast                 Egg White Delight       135.0
# 2  McDondalds      breakfast                  Sausage McMuffin       111.0
# 3  McDondalds      breakfast         Sausage McMuffin with Egg       161.0
# 4  McDondalds      breakfast  Sausage McMuffin with Egg Whites       161.0
#
#   serve_size_unit  calories_kcal  total_fat_g  saturated_fat_g  trans_fat_g  \
# 0               g            300         13.0              5.0          0.0
# 1               g            250          8.0              3.0          0.0
# 2               g            370         23.0              8.0          0.0
# 3               g            450         28.0             10.0          0.0
# 4               g            400         23.0              8.0          0.0
#
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#            chain category_clean                          item_name  \
# 0     McDondalds      breakfast                       Egg McMuffin
# 1     McDondalds      breakfast                  Egg White Delight
# 2     McDondalds      breakfast                   Sausage McMuffin
# 3     McDondalds      breakfast          Sausage McMuffin with Egg
# 4     McDondalds      breakfast   Sausage McMuffin with Egg Whites
# ..           ...            ...                                ...
# 554  burger_king       beverage    BK® Café Mocha Frappe- 16 fl oz
# 555  burger_king       beverage    BK® Café Mocha Frappe- 20 fl oz
# 556  burger_king       beverage  BK® Café Caramel Frappe- 12 fl oz
# 557  burger_king       beverage  BK® Café Caramel Frappe- 16 fl oz
# 558  burger_king       beverage  BK® Café Caramel Frappe- 20 fl oz
#
#      serve_size serve_size_unit  calories_kcal  total_fat_g  saturated_fat_g  \
# 0        136.00               g            300         13.0              5.0
# ...

# %%
df.loc[df["item_name"].str.contains("Honey Mustard Dipping"), "category_clean"] = "sauce"
df.loc[df["item_name"].str.contains("Honey Mustard Dipping")]
# Out:
#            chain category_clean                          item_name  \
# 345  burger_king          sauce  Honey Mustard Dipping Sauce (1oz)
#
#      serve_size serve_size_unit  calories_kcal  total_fat_g  saturated_fat_g  \
# 345        28.0               g             90          6.0              1.0
#
#      trans_fat_g  cholesterol_mg  ...  calories_kcal_norm  total_fat_norm  \
# 345          0.0            10.0  ...              321.43           21.43
#
#      saturated_fat_norm  trans_fat_norm  cholesterol_norm  sodium_norm  \
# 345                3.57             0.0             35.71       642.86
#
#      carbohydrates_norm  dietary_fiber_norm  sugars_norm  protein_norm
# 345               28.57                 0.0         25.0           0.0
#
# [1 rows x 25 columns]

# %%
df.loc[df["item_name"].str.contains("Ketchup"), "category_clean"] = "sauce"

# %%
df.loc[df["item_name"].str.contains("Mayonnaise ")]
# Out:
#            chain category_clean            item_name  serve_size  \
# 338  burger_king      breakfast  Mayonnaise (Packet)        12.0
#
#     serve_size_unit  calories_kcal  total_fat_g  saturated_fat_g  trans_fat_g  \
# 338               g             80          9.0              0.5          0.0
#
#      cholesterol_mg  ...  calories_kcal_norm  total_fat_norm  \
# 338            10.0  ...              666.67            75.0
#
#      saturated_fat_norm  trans_fat_norm  cholesterol_norm  sodium_norm  \
# 338                4.17             0.0             83.33        625.0
#
#      carbohydrates_norm  dietary_fiber_norm  sugars_norm  protein_norm
# 338                8.33                 0.0          0.0           0.0
#
# [1 rows x 25 columns]

# %%
df.iloc[97,1] = "sauce"

# %%
df.loc[df["item_name"].str.contains("Ranch Dipping"),"category_clean"] = "sauce"

# %%
df.loc[df["item_name"].str.contains("Zesty"), "category_clean"] = "sauce"

# %%
df.loc[df["item_name"].str.contains("Chicken Fries")]
# Out:
#            chain category_clean              item_name  serve_size  \
# 278  burger_king         burger  Chicken Fries - 9 pc.        91.0
#
#     serve_size_unit  calories_kcal  total_fat_g  saturated_fat_g  trans_fat_g  \
# 278               g            280         17.0              2.5          0.0
#
#      cholesterol_mg  ...  calories_kcal_norm  total_fat_norm  \
# 278            35.0  ...              307.69           18.68
#
#      saturated_fat_norm  trans_fat_norm  cholesterol_norm  sodium_norm  \
# 278                2.75             0.0             38.46       934.07
#
#      carbohydrates_norm  dietary_fiber_norm  sugars_norm  protein_norm
# 278               21.98                 1.1          1.1         14.29
#
# [1 rows x 25 columns]

# %%
df.loc[df["item_name"].str.contains("McWrap Chicken"), "category_clean"] = "wrap"

# %%
df.loc[df["item_name"].str.contains("Pepperoni")]
# Out:
#       chain category_clean  item_name  serve_size serve_size_unit  \
# 165  subway        dessert  Pepperoni        18.0               g
# 211  subway          extra  Pepperoni        18.0               g
#
#      calories_kcal  total_fat_g  saturated_fat_g  trans_fat_g  cholesterol_mg  \
# 165             80          7.0              NaN          0.0            20.0
# 211             80          7.0              NaN          0.0            20.0
#
#      ...  calories_kcal_norm  total_fat_norm  saturated_fat_norm  \
# 165  ...              444.44           38.89                 NaN
# 211  ...              444.44           38.89                 NaN
#
#      trans_fat_norm  cholesterol_norm  sodium_norm  carbohydrates_norm  \
# 165             0.0            111.11      1666.67                5.56
# 211             0.0            111.11      1611.11                5.56
#
#      dietary_fiber_norm  sugars_norm  protein_norm
# 165                 0.0          0.0         16.67
# ...

# %%
df = df.drop(df.index[165])

# %%
df.loc[df["item_name"].str.contains("Pepperoni")]
# Out:
#       chain category_clean  item_name  serve_size serve_size_unit  \
# 211  subway          extra  Pepperoni        18.0               g
#
#      calories_kcal  total_fat_g  saturated_fat_g  trans_fat_g  cholesterol_mg  \
# 211             80          7.0              NaN          0.0            20.0
#
#      ...  calories_kcal_norm  total_fat_norm  saturated_fat_norm  \
# 211  ...              444.44           38.89                 NaN
#
#      trans_fat_norm  cholesterol_norm  sodium_norm  carbohydrates_norm  \
# 211             0.0            111.11      1611.11                5.56
#
#      dietary_fiber_norm  sugars_norm  protein_norm
# 211                 0.0          0.0         16.67
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Exporting final data frame

# %%
df.to_csv("../00_data/00_comibined_clean_normalized.csv", index=False)
